# %%
# Out:
# ['nitesh', 'ashim', 'Arun', 'sumit', 'ram', 'sam']

# %%
member=["Nitesh","Ashim","Arun","Sumit"]

tasks = {
    "Nitesh": "Papers",
    "Ashim": "field visit",
    "Arun": "Documantion",
    "Sumit": "advitisement"
}
expenses = {
    "Nitesh": 1000,
    "Ashim": 4000,
    "Arun": 500,
    "Sumit": 4500
}

# %%
def show_members(member_list):

    print("Group Members:")

    for member in member_list:
        print(member)

# %%
def show_tasks(task_dict):
    if not task_dict:
        print("No tasks available")
        return

    print("\nTasks :")
    for name, task in task_dict.items():
        print(name, "->", task)

# %%
def split_expenses(member_list, expense_dict):
    total = sum(expense_dict.values())
    per_person = total / len(member_list)

    print("\nTotal Expense:", total)
    print("Each Person Should Pay:", per_person)

    print("\nBalance Sheet:")
    for person in member_list:
        balance = expense_dict[person] - per_person

        if balance > 0:
            print(person, "will get", balance)
        elif balance < 0:
            print(person, "should pay", abs(balance))
        else:
            print(person, "is paid")

# %%
def result():
    show_members(member)
    show_tasks(tasks)
    split_expenses(member, expenses)

# %%
result()
# Out:
# Group Members:
# Nitesh
# Ashim
# Arun
# Sumit
#
# Tasks :
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 result()
#
# Cell In[45], line 3, in result()
#       1 def result():
#       2     show_members(member)
# ----> 3     show_tasks(tasks)
#       4     split_expenses(member, expenses)
#
# Cell In[43], line 7, in show_tasks(task_dict)
#       4     return
#       6 print("\nTasks :")
# ----> 7 for name, task in task_dict.items():
#       8     print(name, "->", task)
#
# AttributeError: 'function' object has no attribute 'items'
