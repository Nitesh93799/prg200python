# %%
def sum(x,y):
    z = x+y
    print(f"The sum of two of{x} and {y} is {z}")
sum(2,5)
sum(5,55)
# Out:
# The sum of two of2 and 5 is 7
# The sum of two of5 and 55 is 60

# %%
def square(l,w):
    c=l*w
    print("The area of square is:",c)
square(5,4)
# Out:
# The area of square is: 20

# %%
def square(l,w):
    
    c=l*w
    print("The area of square is:",c)
l =int(input("Enter a length:"))
w =int(input("Enter a width:"))
square(l,w)
# Out:
# Enter a length: 5
# Enter a width: 4
# The area of square is: 20
